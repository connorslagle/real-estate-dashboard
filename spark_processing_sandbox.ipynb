# %%
from os.path import expanduser, join, abspath

from pyspark.sql import SparkSession
from pyspark.sql.functions import from_json

warehouse_location = abspath('spark-warehouse')

# Initialize Spark Session
spark = SparkSession \
    .builder \
    .appName("Listings processing") \
    .config("spark.sql.warehouse.dir", warehouse_location) \
    .enableHiveSupport() \
    .getOrCreate()

# %%
from pyspark.sql.functions import explode

# %%
df = spark.read.json('data_pipelines/mnt/airflow/dags/files/listings_query.json')

# %%
df.printSchema()
# Out:
# root
#  |-- meta: struct (nullable = true)
#  |    |-- build: string (nullable = true)
#  |    |-- matching_rows: long (nullable = true)
#  |    |-- returned_rows: long (nullable = true)
#  |    |-- schema: string (nullable = true)
#  |    |-- tracking: string (nullable = true)
#  |    |-- tracking_params: struct (nullable = true)
#  |    |    |-- channel: string (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- county: string (nullable = true)
#  |    |    |-- listingActivity: string (nullable = true)
#  |    |    |-- neighborhood: string (nullable = true)
#  |    |    |-- propertyStatus: string (nullable = true)
#  |    |    |-- propertyType: string (nullable = true)
#  |    |    |-- searchBathrooms: string (nullable = true)
#  |    |    |-- searchBedrooms: string (nullable = true)
#  |    |    |-- searchCityState: string (nullable = true)
#  |    |    |-- searchCoordinates: string (nullable = true)
#  |    |    |-- searchHouseSqft: string (nullable = true)
#  |    |    |-- searchLotSqft: string (nullable = true)
#  |    |    |-- searchMaxPrice: string (nullable = true)
#  |    |    |-- searchMinPrice: string (nullable = true)
#  |    |    |-- searchRadius: string (nullable = true)
#  |    |    |-- searchResults: string (nullable = true)
#  |    |    |-- siteSection: string (nullable = true)
#  |    |    |-- sortResults: string (nullable = true)
#  |    |    |-- srpPropertyStatus: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- version: string (nullable = true)
#  |    |    |-- zip: string (nullable = true)
#  |-- properties: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- address: struct (nullable = true)
#  |    |    |    |-- city: string (nullable = true)
#  |    |    |    |-- county: string (nullable = true)
#  |    |    |    |-- fips_code: string (nullable = true)
#  |    |    |    |-- lat: double (nullable = true)
#  |    |    |    |-- line: string (nullable = true)
#  |    |    |    |-- lon: double (nullable = true)
#  |    |    |    |-- neighborhood_name: string (nullable = true)
#  |    |    |    |-- postal_code: string (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- state_code: string (nullable = true)
#  |    |    |-- agents: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- advertiser_id: string (nullable = true)
#  |    |    |    |    |-- id: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |    |-- primary: boolean (nullable = true)
#  |    |    |-- baths: long (nullable = true)
#  |    |    |-- baths_full: long (nullable = true)
#  |    |    |-- baths_half: long (nullable = true)
#  |    |    |-- beds: long (nullable = true)
#  |    |    |-- branding: struct (nullable = true)
#  |    |    |    |-- listing_office: struct (nullable = true)
#  |    |    |    |    |-- list_item: struct (nullable = true)
#  |    |    |    |    |    |-- accent_color: string (nullable = true)
#  |    |    |    |    |    |-- link: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- phone: string (nullable = true)
#  |    |    |    |    |    |-- photo: string (nullable = true)
#  |    |    |    |    |    |-- show_realtor_logo: boolean (nullable = true)
#  |    |    |    |    |    |-- slogan: string (nullable = true)
#  |    |    |-- building_size: struct (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- units: string (nullable = true)
#  |    |    |-- client_display_flags: struct (nullable = true)
#  |    |    |    |-- advantage_pro_flag: boolean (nullable = true)
#  |    |    |    |-- has_matterport: boolean (nullable = true)
#  |    |    |    |-- has_open_house: boolean (nullable = true)
#  |    |    |    |-- is_active_under_contract: boolean (nullable = true)
#  |    |    |    |-- is_co_broke_email: boolean (nullable = true)
#  |    |    |    |-- is_co_broke_phone: boolean (nullable = true)
#  |    |    |    |-- is_new_construction: boolean (nullable = true)
#  |    |    |    |-- is_new_listing: boolean (nullable = true)
#  |    |    |    |-- is_new_plan: boolean (nullable = true)
#  |    |    |    |-- is_office_standard_listing: boolean (nullable = true)
#  |    |    |    |-- is_pending: boolean (nullable = true)
#  |    |    |    |-- is_showcase: boolean (nullable = true)
#  |    |    |    |-- is_showcase_choice_enabled: boolean (nullable = true)
#  |    |    |    |-- is_turbo: boolean (nullable = true)
#  |    |    |    |-- lead_form_phone_required: boolean (nullable = true)
#  |    |    |    |-- presentation_status: string (nullable = true)
#  |    |    |    |-- price_change: long (nullable = true)
#  |    |    |    |-- show_contact_a_lender_in_lead_form: boolean (nullable = true)
#  |    |    |    |-- show_veterans_united_in_lead_form: boolean (nullable = true)
#  |    |    |    |-- suppress_map_pin: boolean (nullable = true)
#  |    |    |-- data_source_name: string (nullable = true)
#  |    |    |-- last_update: string (nullable = true)
#  |    |    |-- lead_forms: struct (nullable = true)
#  |    |    |    |-- cashback_enabled: boolean (nullable = true)
#  |    |    |    |-- flip_the_market_enabled: boolean (nullable = true)
#  |    |    |    |-- form: struct (nullable = true)
#  |    |    |    |    |-- email: struct (nullable = true)
#  |    |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |    |-- message: struct (nullable = true)
#  |    |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |    |-- name: struct (nullable = true)
#  |    |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |    |-- phone: struct (nullable = true)
#  |    |    |    |    |    |-- maximum_character_count: long (nullable = true)
#  |    |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |    |-- show: boolean (nullable = true)
#  |    |    |    |-- form_type: string (nullable = true)
#  |    |    |    |-- is_lcm_enabled: boolean (nullable = true)
#  |    |    |    |-- lead_type: string (nullable = true)
#  |    |    |    |-- show_agent: boolean (nullable = true)
#  |    |    |    |-- show_broker: boolean (nullable = true)
#  |    |    |    |-- show_builder: boolean (nullable = true)
#  |    |    |    |-- show_contact_a_lender: boolean (nullable = true)
#  |    |    |    |-- show_text_leads: boolean (nullable = true)
#  |    |    |    |-- show_veterans_united: boolean (nullable = true)
#  |    |    |    |-- smarthome_enabled: boolean (nullable = true)
#  |    |    |-- list_tracking: string (nullable = true)
#  |    |    |-- listing_id: string (nullable = true)
#  |    |    |-- lot_size: struct (nullable = true)
#  |    |    |    |-- size: long (nullable = true)
#  |    |    |    |-- units: string (nullable = true)
#  |    |    |-- mls: struct (nullable = true)
#  |    |    |    |-- abbreviation: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- plan_id: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |-- office: struct (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |-- page_no: long (nullable = true)
#  |    |    |-- photo_count: long (nullable = true)
#  |    |    |-- price: long (nullable = true)
#  |    |    |-- products: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- prop_status: string (nullable = true)
#  |    |    |-- prop_sub_type: string (nullable = true)
#  |    |    |-- prop_type: string (nullable = true)
#  |    |    |-- property_id: string (nullable = true)
#  |    |    |-- rank: long (nullable = true)
#  |    |    |-- rdc_web_url: string (nullable = true)
#  |    |    |-- thumbnail: string (nullable = true)
#  |    |    |-- virtual_tour: struct (nullable = true)
#  |    |    |    |-- href: string (nullable = true)

# %%
df_test = df.select(df.meta, explode(df.properties))

# %%
df_test.printSchema()
# Out:
# root
#  |-- meta: struct (nullable = true)
#  |    |-- build: string (nullable = true)
#  |    |-- matching_rows: long (nullable = true)
#  |    |-- returned_rows: long (nullable = true)
#  |    |-- schema: string (nullable = true)
#  |    |-- tracking: string (nullable = true)
#  |    |-- tracking_params: struct (nullable = true)
#  |    |    |-- channel: string (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- county: string (nullable = true)
#  |    |    |-- listingActivity: string (nullable = true)
#  |    |    |-- neighborhood: string (nullable = true)
#  |    |    |-- propertyStatus: string (nullable = true)
#  |    |    |-- propertyType: string (nullable = true)
#  |    |    |-- searchBathrooms: string (nullable = true)
#  |    |    |-- searchBedrooms: string (nullable = true)
#  |    |    |-- searchCityState: string (nullable = true)
#  |    |    |-- searchCoordinates: string (nullable = true)
#  |    |    |-- searchHouseSqft: string (nullable = true)
#  |    |    |-- searchLotSqft: string (nullable = true)
#  |    |    |-- searchMaxPrice: string (nullable = true)
#  |    |    |-- searchMinPrice: string (nullable = true)
#  |    |    |-- searchRadius: string (nullable = true)
#  |    |    |-- searchResults: string (nullable = true)
#  |    |    |-- siteSection: string (nullable = true)
#  |    |    |-- sortResults: string (nullable = true)
#  |    |    |-- srpPropertyStatus: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- version: string (nullable = true)
#  |    |    |-- zip: string (nullable = true)
#  |-- col: struct (nullable = true)
#  |    |-- address: struct (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- county: string (nullable = true)
#  |    |    |-- fips_code: string (nullable = true)
#  |    |    |-- lat: double (nullable = true)
#  |    |    |-- line: string (nullable = true)
#  |    |    |-- lon: double (nullable = true)
#  |    |    |-- neighborhood_name: string (nullable = true)
#  |    |    |-- postal_code: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- state_code: string (nullable = true)
#  |    |-- agents: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- advertiser_id: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- primary: boolean (nullable = true)
#  |    |-- baths: long (nullable = true)
#  |    |-- baths_full: long (nullable = true)
#  |    |-- baths_half: long (nullable = true)
#  |    |-- beds: long (nullable = true)
#  |    |-- branding: struct (nullable = true)
#  |    |    |-- listing_office: struct (nullable = true)
#  |    |    |    |-- list_item: struct (nullable = true)
#  |    |    |    |    |-- accent_color: string (nullable = true)
#  |    |    |    |    |-- link: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- phone: string (nullable = true)
#  |    |    |    |    |-- photo: string (nullable = true)
#  |    |    |    |    |-- show_realtor_logo: boolean (nullable = true)
#  |    |    |    |    |-- slogan: string (nullable = true)
#  |    |-- building_size: struct (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- units: string (nullable = true)
#  |    |-- client_display_flags: struct (nullable = true)
#  |    |    |-- advantage_pro_flag: boolean (nullable = true)
#  |    |    |-- has_matterport: boolean (nullable = true)
#  |    |    |-- has_open_house: boolean (nullable = true)
#  |    |    |-- is_active_under_contract: boolean (nullable = true)
#  |    |    |-- is_co_broke_email: boolean (nullable = true)
#  |    |    |-- is_co_broke_phone: boolean (nullable = true)
#  |    |    |-- is_new_construction: boolean (nullable = true)
#  |    |    |-- is_new_listing: boolean (nullable = true)
#  |    |    |-- is_new_plan: boolean (nullable = true)
#  |    |    |-- is_office_standard_listing: boolean (nullable = true)
#  |    |    |-- is_pending: boolean (nullable = true)
#  |    |    |-- is_showcase: boolean (nullable = true)
#  |    |    |-- is_showcase_choice_enabled: boolean (nullable = true)
#  |    |    |-- is_turbo: boolean (nullable = true)
#  |    |    |-- lead_form_phone_required: boolean (nullable = true)
#  |    |    |-- presentation_status: string (nullable = true)
#  |    |    |-- price_change: long (nullable = true)
#  |    |    |-- show_contact_a_lender_in_lead_form: boolean (nullable = true)
#  |    |    |-- show_veterans_united_in_lead_form: boolean (nullable = true)
#  |    |    |-- suppress_map_pin: boolean (nullable = true)
#  |    |-- data_source_name: string (nullable = true)
#  |    |-- last_update: string (nullable = true)
#  |    |-- lead_forms: struct (nullable = true)
#  |    |    |-- cashback_enabled: boolean (nullable = true)
#  |    |    |-- flip_the_market_enabled: boolean (nullable = true)
#  |    |    |-- form: struct (nullable = true)
#  |    |    |    |-- email: struct (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- message: struct (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- name: struct (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- phone: struct (nullable = true)
#  |    |    |    |    |-- maximum_character_count: long (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- show: boolean (nullable = true)
#  |    |    |-- form_type: string (nullable = true)
#  |    |    |-- is_lcm_enabled: boolean (nullable = true)
#  |    |    |-- lead_type: string (nullable = true)
#  |    |    |-- show_agent: boolean (nullable = true)
#  |    |    |-- show_broker: boolean (nullable = true)
#  |    |    |-- show_builder: boolean (nullable = true)
#  |    |    |-- show_contact_a_lender: boolean (nullable = true)
#  |    |    |-- show_text_leads: boolean (nullable = true)
#  |    |    |-- show_veterans_united: boolean (nullable = true)
#  |    |    |-- smarthome_enabled: boolean (nullable = true)
#  |    |-- list_tracking: string (nullable = true)
#  |    |-- listing_id: string (nullable = true)
#  |    |-- lot_size: struct (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- units: string (nullable = true)
#  |    |-- mls: struct (nullable = true)
#  |    |    |-- abbreviation: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- plan_id: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- office: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |-- page_no: long (nullable = true)
#  |    |-- photo_count: long (nullable = true)
#  |    |-- price: long (nullable = true)
#  |    |-- products: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- prop_status: string (nullable = true)
#  |    |-- prop_sub_type: string (nullable = true)
#  |    |-- prop_type: string (nullable = true)
#  |    |-- property_id: string (nullable = true)
#  |    |-- rank: long (nullable = true)
#  |    |-- rdc_web_url: string (nullable = true)
#  |    |-- thumbnail: string (nullable = true)
#  |    |-- virtual_tour: struct (nullable = true)
#  |    |    |-- href: string (nullable = true)

# %%
df_properties = df.select(explode(df.properties))

# %%
df_properties.printSchema()
# Out:
# root
#  |-- col: struct (nullable = true)
#  |    |-- address: struct (nullable = true)
#  |    |    |-- city: string (nullable = true)
#  |    |    |-- county: string (nullable = true)
#  |    |    |-- fips_code: string (nullable = true)
#  |    |    |-- lat: double (nullable = true)
#  |    |    |-- line: string (nullable = true)
#  |    |    |-- lon: double (nullable = true)
#  |    |    |-- neighborhood_name: string (nullable = true)
#  |    |    |-- postal_code: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- state_code: string (nullable = true)
#  |    |-- agents: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- advertiser_id: string (nullable = true)
#  |    |    |    |-- id: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- photo: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- primary: boolean (nullable = true)
#  |    |-- baths: long (nullable = true)
#  |    |-- baths_full: long (nullable = true)
#  |    |-- baths_half: long (nullable = true)
#  |    |-- beds: long (nullable = true)
#  |    |-- branding: struct (nullable = true)
#  |    |    |-- listing_office: struct (nullable = true)
#  |    |    |    |-- list_item: struct (nullable = true)
#  |    |    |    |    |-- accent_color: string (nullable = true)
#  |    |    |    |    |-- link: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- phone: string (nullable = true)
#  |    |    |    |    |-- photo: string (nullable = true)
#  |    |    |    |    |-- show_realtor_logo: boolean (nullable = true)
#  |    |    |    |    |-- slogan: string (nullable = true)
#  |    |-- building_size: struct (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- units: string (nullable = true)
#  |    |-- client_display_flags: struct (nullable = true)
#  |    |    |-- advantage_pro_flag: boolean (nullable = true)
#  |    |    |-- has_matterport: boolean (nullable = true)
#  |    |    |-- has_open_house: boolean (nullable = true)
#  |    |    |-- is_active_under_contract: boolean (nullable = true)
#  |    |    |-- is_co_broke_email: boolean (nullable = true)
#  |    |    |-- is_co_broke_phone: boolean (nullable = true)
#  |    |    |-- is_new_construction: boolean (nullable = true)
#  |    |    |-- is_new_listing: boolean (nullable = true)
#  |    |    |-- is_new_plan: boolean (nullable = true)
#  |    |    |-- is_office_standard_listing: boolean (nullable = true)
#  |    |    |-- is_pending: boolean (nullable = true)
#  |    |    |-- is_showcase: boolean (nullable = true)
#  |    |    |-- is_showcase_choice_enabled: boolean (nullable = true)
#  |    |    |-- is_turbo: boolean (nullable = true)
#  |    |    |-- lead_form_phone_required: boolean (nullable = true)
#  |    |    |-- presentation_status: string (nullable = true)
#  |    |    |-- price_change: long (nullable = true)
#  |    |    |-- show_contact_a_lender_in_lead_form: boolean (nullable = true)
#  |    |    |-- show_veterans_united_in_lead_form: boolean (nullable = true)
#  |    |    |-- suppress_map_pin: boolean (nullable = true)
#  |    |-- data_source_name: string (nullable = true)
#  |    |-- last_update: string (nullable = true)
#  |    |-- lead_forms: struct (nullable = true)
#  |    |    |-- cashback_enabled: boolean (nullable = true)
#  |    |    |-- flip_the_market_enabled: boolean (nullable = true)
#  |    |    |-- form: struct (nullable = true)
#  |    |    |    |-- email: struct (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- message: struct (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- name: struct (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- phone: struct (nullable = true)
#  |    |    |    |    |-- maximum_character_count: long (nullable = true)
#  |    |    |    |    |-- minimum_character_count: long (nullable = true)
#  |    |    |    |    |-- required: boolean (nullable = true)
#  |    |    |    |-- show: boolean (nullable = true)
#  |    |    |-- form_type: string (nullable = true)
#  |    |    |-- is_lcm_enabled: boolean (nullable = true)
#  |    |    |-- lead_type: string (nullable = true)
#  |    |    |-- show_agent: boolean (nullable = true)
#  |    |    |-- show_broker: boolean (nullable = true)
#  |    |    |-- show_builder: boolean (nullable = true)
#  |    |    |-- show_contact_a_lender: boolean (nullable = true)
#  |    |    |-- show_text_leads: boolean (nullable = true)
#  |    |    |-- show_veterans_united: boolean (nullable = true)
#  |    |    |-- smarthome_enabled: boolean (nullable = true)
#  |    |-- list_tracking: string (nullable = true)
#  |    |-- listing_id: string (nullable = true)
#  |    |-- lot_size: struct (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- units: string (nullable = true)
#  |    |-- mls: struct (nullable = true)
#  |    |    |-- abbreviation: string (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- plan_id: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |-- office: struct (nullable = true)
#  |    |    |-- id: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |-- page_no: long (nullable = true)
#  |    |-- photo_count: long (nullable = true)
#  |    |-- price: long (nullable = true)
#  |    |-- products: array (nullable = true)
#  |    |    |-- element: string (containsNull = true)
#  |    |-- prop_status: string (nullable = true)
#  |    |-- prop_sub_type: string (nullable = true)
#  |    |-- prop_type: string (nullable = true)
#  |    |-- property_id: string (nullable = true)
#  |    |-- rank: long (nullable = true)
#  |    |-- rdc_web_url: string (nullable = true)
#  |    |-- thumbnail: string (nullable = true)
#  |    |-- virtual_tour: struct (nullable = true)
#  |    |    |-- href: string (nullable = true)

# %%
df.createOrReplaceTempView('listings_query')
df_test.createOrReplaceTempView('properties_table')

# %%
"""
property_id STRING,
query_date TIMESTAMP,
query_city STRING,
query_state STRING,

prop_type STRING,
address_line STRING,
address_city STRING,
zip_code INT,
fips_code INT,
lat DECIMAL(9,6),
long DECIMAL(9,6),
neighborhood STRING,

listing_price DOUBLE,
baths DOUBLE,
beds INT,
building_size INT,
building_size_units STRING,
lot_size INT,
lot_size_units STRING,
last_update TIMESTAMP,
url STRING
"""

df_to_insert = spark.sql('''
    SELECT
        col.`property_id`,
        current_date() AS query_date,
        meta.`tracking_params`.`city` AS query_city,
        meta.`tracking_params`.`state` AS query_state,
        col.`prop_type`,
        col.`address`.`line` AS address_line,
        col.`address`.`city` AS address_city,
        col.`address`.`postal_code` AS zip_code,
        col.`address`.`fips_code` AS fips_code,
        col.`address`.`lat` AS lat,
        col.`address`.`lon` AS lon,
        col.`address`.`neighborhood_name` as neighborhood,
        col.`price` AS listing_price,
        col.`baths`,
        col.`beds`,
        col.`building_size`.`size` AS building_size,
        col.`building_size`.`units` AS building_size_units,
        col.`lot_size`.`size` AS lot_size,
        col.`lot_size`.`units` AS lot_size_units,
        col.`last_update`,
        col.`rdc_web_url` AS url        
    FROM
        properties_table
''')

# %%
type(df_to_insert)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
type(df)
# Out:
# pyspark.sql.dataframe.DataFrame

# %%
df.select('properties')
# Out:
# Column<b'properties'>
